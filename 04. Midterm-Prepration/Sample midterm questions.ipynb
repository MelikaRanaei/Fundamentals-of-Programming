# %% [markdown]
# <style>
# .aligncenter {
#     text-align: center;
# }
# </style>
# <p class="aligncenter">
#     <img src = "https://production-media.paperswithcode.com/datasets/DomainNet-0000002698-42f300d8_nfcNmI7.jpg"  width=70%>
# </p>

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2 align="center">Domain Clustering</h2>
#     <h3 align="center">Computational Inteligence - Project 01</h3>
#     <h3 align="center">Ferdowsi University of Mashhad</h3>
#     <h4 align="center"><a href="https://t.me/afsharino">Mohammad Afshari</a></h4>
#     <h4 align="center"><a href="https://t.me/saleh_shv">Saleh Shirvani</a></h4>
# </div>

# %%
<div class="alert alert-block alert-info">
    <h2 align="center">Domain Clustering</h2>
    <h3 align="center">Computational Inteligence - Project 01</h3>
    <h3 align="center">Ferdowsi University of Mashhad</h3>
    <h4 align="center"><a href="https://t.me/afsharino">Mohammad Afshari</a></h4>
    <h4 align="center"><a href="https://t.me/saleh_shv">Saleh Shirvani</a></h4>
</div>

# %% [markdown]
# ## **Table of contents**<a id='toc0_'></a>
# - [Base:](#toc1_)
#   - [No Real Length Limit](#toc1_1_)
#   - [Decimal Representation](#toc1_2_)
#   - [Number Bases](#toc1_3_)
#   - [Type of Integers](#toc1_4_)
# - [Floating-Point Numbers](#toc2_)
# - [Complex Numbers](#toc3_)
# - [Strings](#toc4_)
#   - [Basic Representation of Strings](#toc4_1_)
#   - [Including Quotes in Strings](#toc4_2_)
#   - [Escape Sequences in Strings](#toc4_3_)
#     - [Suppressing Special Character Meaning](#toc4_3_1_)
#     - [Applying Special Meaning to Characters](#toc4_3_2_)
#   - [Raw Strings](#toc4_4_)
#   - [Triple-Quoted Strings](#toc4_5_)
# - [Boolean Type](#toc5_)
# - [Conclusion](#toc6_)

# %% [markdown]
# ## <a id='toc1_'></a>[Base (Radix):](#toc0_)

# %% [markdown]
# ## Convert the following numbers to the desired base
#
# ### Type 1
# 1. $(63)_{10} = (?)_{2}$
# 2. $(93)_{10} = (?)_{2}$
# 3. $(87)_{10} = (?)_{2}$
# 4. $(78)_{10} = (?)_{2}$
# 5. $(472)_{10} = (?)_{2}$
# > <details>
#     <summary class='alert alert-success text-center'><h1> Solution 💡</h1></summary>
#     <br/>
#     <p align="center">
#         As we know, to convert any integer number from base 10 to base r, we use successive division technique. consider the following examples:
#         <br/>
#         <img src="../images/base10tor.png" width="420" height="165"/>
#     </p>
#     <p align="center">
#         According to the above examples, the answers are as follows:
#         <br/>
#     </p>
#         1. $(63)_{10} = (11 1111)_{2}$
#         <br/>
#         2. $(93)_{10} = (101 1101)_{2}$
#         <br/>
#         3. $(87)_{10} = (101 0111)_{2}$
#         <br/>
#         4. $(78)_{10} = (100 1110)_{2}$
#         <br/>
#         5. $(472)_{10} = (1 1101 1000)_{2}$
# </details>
#
# ### Type 2
#
# 1. $(45.21)_{10} = (?)_{2}$
# > <details>
#     <summary class='alert alert-success text-center'><h1> Solution 💡</h1></summary>
#     <br/>
#     <p align="center">
#         As we know, to convert any decimal number from base 10 to base r, we divide the straight part by r in a row and multiply the decimal part by r in a row. consider the following examples:
#         <br/>
#         <img src="../images/base10tor-decimal.png" width="420" height="165"/>
#         <img src="../images/base10tor-decimal1.png" width="420" height="165"/>
#     </p>
#     <p align="center">
#         According to the above example, the answers is as follows:
#         <br/>
#     </p>
#         1. $(45.21)_{10} = (10 1101.0011...)_{2}$
# </details>
#
# ### Type 3
# 1. $(101101)_{2} =(?)_{8} = (?)_{16} = (?)_{10}$
# 2. $(1010011)_{2} =(?)_{8} = (?)_{16} = (?)_{10}$
# 3. $(1000011)_{2} =(?)_{8} = (?)_{16} = (?)_{10}$
# 4. $(11001101)_{2} =(?)_{8} = (?)_{16}$
# > <details>
#     <summary class='alert alert-success text-center'><h1> Solution 💡</h1></summary>
#     <br/>
#     <p align="center">
#         Converting from binary to octal is achieved simply by dividing the binary number into groups of three digits on both sides of the binary point. Then each group is given a number based on eight. The following example shows the relevant procedure:
#         <br/>
#         <img src="../images/base2to8.png" width="420" height="165"/>
#     </p>
#     <p align="center">
#         Converting from base two to base hexadecimal is similar to the above process, with the difference that binary numbers are divided into four-digit groups.
#         <br/>
#         <img src="../images/base2to16.png" width="420" height="165"/>
#     </p>
#     <p align="center">
#         According to the above example, the answers is as follows:
#         <br/>
#     </p>
#         1. $(101101)_{2} =(55)_{8} = (2D)_{16} = (45)_{10}$
#         <br/>
#         2. $(1010011)_{2} =(123)_{8} = (53)_{16} = (83)_{10}$
#         <br/>
#         3. $(1000011)_{2} =(103)_{8} = (43)_{16} = (67)_{10}$
#         <br/>
#         4. $(11001101)_{2} =(315)_{8} = (CD)_{16}$
# </details>
#
# ### Type 4
# 1. $ (1001001.101101)_{2} = (?)_{10} $
# 2. $ (1001101.101001)_{2} = (?)_{10} $
# 3. $ (1111001.101001)_{2} = (?)_{10} $
# > <details>
#     <summary class='alert alert-success text-center'><h1> Solution 💡</h1></summary>
#     <br/>
#     <p align="center">
#         To convert a number from base r to base 10, we first value that number and then use the property of multiplication.. consider the following examples:
#         <br/>
#         <img src="../images/baserto10.png" width="420" height="165"/>
#         <img src="../images/baserto10-1.png" width="420" height="165"/>
#     </p>
#     <p align="center">
#         According to the above examples, the answers are as follows:
#         <br/>
#     </p>
#         1. $ (1001001.101101)_{2} = (?)_{10} $
#         <br/>
#         2. $ (1001101.101001)_{2} = (?)_{10} $
#         <br/>
#         3. $ (1111001.101001)_{2} = (?)_{10} $
# </details>

# %% [markdown]
# <details>
#     <summary class='alert alert-success text-center'><h1> Solution 💡</h1></summary>
#     <br/>
#     <p align="center">
#         To convert a number from base r to base 10, we first value that number and then use the property of multiplication.. consider the following examples:
#         <br/>
#         <img src="../images/baserto10.png" width="420" height="165"/>
#         <img src="../images/baserto10-1.png" width="420" height="165"/>
#     </p>
#     <p align="center">
#         According to the above examples, the answers are as follows:
#         <br/>
#     </p>
#         1. $ (1001001.101101)_{2} = (?)_{10} $
#         <br/>
#         2. $ (1001101.101001)_{2} = (?)_{10} $
#         <br/>
#         3. $ (1111001.101001)_{2} = (?)_{10} $
# </details>

# %% [markdown]
# ## Obtain the result of the following expressions by the 2nd complement method
# 1. 45 - 23 = ?
# 2. file 3
# 3. file 4
# 4. file 5

# %% [markdown]
# ## Fill the Blank
# - In the sign bit, --- is used to show that the number is positive and --- is used to show that it is negative.
# - To change the base of the number 15 in base m to base n so that m>n, the method of successive --- should be used.

# %% [markdown]
# # Algorithm & Flowchart

# %% [markdown]
# ## For the following questions, write the algorithm and draw its flowchart
# 1. Draw a flowchart that, upon receiving the number n from the input, if the number is even, it will print the remainder divided by 10 in the output, and if the number is odd, it will print the Hello World message 2*n times in the output.
# > <details>
#     <summary class='alert alert-success text-center'><h1> Solution 💡</h1></summary>
#     <br/>
#     <p align="center">
#         <img src="../images/flowcharts/1.jpg" width="420" height="165"/>
#     </p>
# </details>
#
# 2. Write an algorithm or draw a flowchart that prints the numbers 1 to n in the output after receiving n from the input.
# > <details>
#     <summary class='alert alert-success text-center'><h1> Solution 💡</h1></summary>
#     <br/>
#     <p align="center">
#         <img src="../images/flowcharts/2.jpg" width="420" height="165"/>
#     </p>
# </details>
#
# 3. Write an algorithm that receives the natural number n from the input and obtains the result of the following series if it is even.
#
# \begin{align}
#     s = \frac{1}{2} + \frac{1}{4} +  ...  + \frac{1}{n}
# \end{align}
#
# > <details>
#     <summary class='alert alert-success text-center'><h1> Solution 💡</h1></summary>
#     <br/>
#     <p align="center">
#         <img src="../images/flowcharts/3.jpg" width="420" height="165"/>
#     </p>
# </details>
#
# 4. Write an algorithm that by taking the value of two variables X and Y from the input, calculates and prints the sum, product, and subtraction of the smaller number from the larger one, as well as the division of the larger value by the smaller one.
# </br>
#
# 5. Write a program that calculates and prints the value of n and x as input parameters and the result of the following series.
# </br>
#
# 6. Draw a flowchart that, upon receiving a value from the input, if the number is even, it will print the remaining number divided by 3 in the output, and if the number is odd, it will print the same number in the output.
# </br>
#
# 7. Write an algorithm or draw a flowchart that prints the message Hello World 2*n times in the output after receiving n from the input.
# </br>
#
# 8. Write an algorithm that obtains and prints the result of the series $\sum\limits_{i=1}^n (i^2)$ after receiving the value of n from the input.
# </br>
#
# 9. Draw a flowchart that, upon receiving the number n from the input, if the value of n>100, it will print its reverse and if it is n<100, it will print its inverse in the output.
#
#     For example, the reverse of 254 is equal to 452 and the inverse of 31 is equal to 1/31
# </br>
#
# 10. Draw a flowchart that, by receiving the number of the day of the year, will determine in which month that number represents a day.
# </br>
#
# 11. Draw a flowchart that, upon receiving a value from the input, if the number is even, it will print the third power in the output, and if the number is odd, it will print the remainder divided by 4 in the output.
# </br>
#
# 12. Draw an algorithm or a flowchart that calculates and prints the sum and difference of two input numbers.
# </br>
#
# 13. Write an algorithm that obtains and prints the series 1 + 13 after receiving the value from the input.
# </br>
#
# 14. Draw a flow chart that, by receiving two 5-digit numbers from the input, calculates and prints the sum of the numbers resulting from the three-digit values.
#
#     For example, suppose two numbers 68214 and 25428 are received from the input. Your algorithm should give the result 936 - 682254.
# </br>
#
# 15. Draw a flowchart that, by receiving the number of the day of the year, will determine the number of the day of the month.

# %% [markdown]
# # Python

# %% [markdown]
# ## What is the output?
#
# 1. What's the output of the following code?
#
#     print("Final Python Exam".find("Python"))
#
#     a) False
#
#     b) True
#
#     c) 6
#
#     d) 5
# </br>
#
# 2. What's the output of the following code?
#
#     str1 = 'Welcome'
#
#     print(str1[:6] + ' ToHouse')
#     </br>
#
# 3. How to move the contents of two variables without using auxiliary variable?
#     </br>
#
# 4. What's the output of the following code?
#
#     print("Dear {1} welcome to learn (0)!!!".format(y,x))
#
#     a) Dear Sara welcome to learn Python!!!
#
#     b) Dear Pyhton welcome to learn Sara!!!
#
#     c) Dear 1 welcome to learn 0!!!
#
#     d) welcome to learn Python Dear Sara!!!
#     </br>
